# %%
#To load data into a pandas DataFrame from a source
import pandas as pd

df = pd.read_excel('EU Superstore.xls')
print (df)
# Out:
#       Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 1          2  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 2          3  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 3          4  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 4          5  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# ...      ...              ...        ...        ...             ...
# 9995    9996  ES-2014-3780358 2014-11-16 2014-11-19     First Class
# 9996    9997  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9997    9998  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9998    9999  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9999   10000  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  \
# 0       AS-10045     Aaron Smayling    Corporate    Leeds  England
# ...

# %%
#we need install package xlrd for read excel
pip install xlrd
# Out:
# ...
#                                               0.0/96.5 kB ? eta -:--:--
#      ----                                     10.2/96.5 kB ? eta -:--:--
#      ----                                     10.2/96.5 kB ? eta -:--:--
#      ----------------                       41.0/96.5 kB 326.8 kB/s eta 0:00:01
#      ------------------------------------   92.2/96.5 kB 521.8 kB/s eta 0:00:01
#      -------------------------------------- 96.5/96.5 kB 501.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#This method returns the first n rows of the DataFrame.By default, it returns the first 5
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class    AS-10045
# 1       2  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class    AS-10045
# 2       3  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class    AS-10045
# 3       4  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class    AS-10045
# 4       5  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class    AS-10045
#
#     Customer Name    Segment   City    State         Country Region  \
# 0  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 1  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 2  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 3  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
# 4  Aaron Smayling  Corporate  Leeds  England  United Kingdom  North
#
#         Product ID         Category Sub-Category  \
# ...

# %%
#This method returns the last n rows of the DataFrame. By default, it returns the last 5 rows
df.tail()
# Out:
#       Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 9995    9996  ES-2014-3780358 2014-11-16 2014-11-19     First Class
# 9996    9997  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9997    9998  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9998    9999  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9999   10000  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  Country  \
# 9995    CC-12100    Chad Cunningham  Home Office   Rovigo   Veneto    Italy
# 9996    GB-14575  Giulietta Baptist     Consumer  Hamburg  Hamburg  Germany
# 9997    GB-14575  Giulietta Baptist     Consumer  Hamburg  Hamburg  Germany
# 9998    GB-14575  Giulietta Baptist     Consumer  Hamburg  Hamburg  Germany
# 9999    GB-14575  Giulietta Baptist     Consumer  Hamburg  Hamburg  Germany
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %%
#This attribute returns a tuple representing the dimensions of the DataFrame (number of rows, number of columns)
df.shape
# Out:
# (10000, 20)

# %%
#This method provides a concise summary of the DataFrame, including the number of non-null values in each column and the data types of the columns
df.info
# Out:
# <bound method DataFrame.info of       Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 1          2  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 2          3  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 3          4  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 4          5  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# ...      ...              ...        ...        ...             ...
# 9995    9996  ES-2014-3780358 2014-11-16 2014-11-19     First Class
# 9996    9997  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9997    9998  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9998    9999  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9999   10000  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  \
# ...

# %%
#This method generates descriptive statistics of the numerical columns in the DataFrame, including count, mean, standard deviation, minimum, maximum, and quartile values
df.describe()
# Out:
#             Row ID         Sales      Quantity      Discount        Profit
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5000.50000    293.808906      3.777300      0.103105     37.282974
# std     2886.89568    486.055635      2.203268      0.174782    178.100384
# min        1.00000      2.955000      1.000000      0.000000  -3059.820000
# 25%     2500.75000     49.462500      2.000000      0.000000      1.320000
# 50%     5000.50000    119.355000      3.000000      0.000000     14.220000
# 75%     7500.25000    320.708625      5.000000      0.100000     48.510000
# max    10000.00000   7958.580000     14.000000      0.850000   3979.080000

# %%
#This attribute returns the column labels of the DataFrame
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#This attribute returns the index labels of the DataFrame
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
#This attribute returns the data types of each column in the DataFrame
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# City                     object
# State                    object
# Country                  object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
#This method returns a DataFrame of the same shape as the original, where each element is a boolean value indicating whether the corresponding element is missing (NaN) or not
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9995   False     False       False      False      False        False
# 9996   False     False       False      False      False        False
# 9997   False     False       False      False      False        False
# 9998   False     False       False      False      False        False
# 9999   False     False       False      False      False        False
#
#       Customer Name  Segment   City  State  Country  Region  Product ID  \
# ...

# %%
#checking data duplicated
df.duplicated
# Out:
# <bound method DataFrame.duplicated of       Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 1          2  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 2          3  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 3          4  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 4          5  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# ...      ...              ...        ...        ...             ...
# 9995    9996  ES-2014-3780358 2014-11-16 2014-11-19     First Class
# 9996    9997  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9997    9998  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9998    9999  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9999   10000  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  \
# ...

# %%
#remove duplicate rows from a DataFrame
df.drop_duplicates()
# Out:
#       Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 1          2  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 2          3  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 3          4  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# 4          5  ES-2017-1311038 2017-02-07 2017-02-11  Standard Class
# ...      ...              ...        ...        ...             ...
# 9995    9996  ES-2014-3780358 2014-11-16 2014-11-19     First Class
# 9996    9997  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9997    9998  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9998    9999  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
# 9999   10000  ES-2015-5371207 2015-01-25 2015-01-29  Standard Class
#
#      Customer ID      Customer Name      Segment     City    State  \
# 0       AS-10045     Aaron Smayling    Corporate    Leeds  England
# ...
